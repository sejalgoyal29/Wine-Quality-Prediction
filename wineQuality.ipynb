# %%
import numpy as np 
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/pradu/OneDrive/Desktop/prg/data/winequalityN.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  type_white  Excellent quality
# 0      8.8        6           1                  0
# 1      9.5        6           1                  0
# 2     10.1        6           1                  0
# 3      9.9        6           1                  0
# 4      9.9        6           1                  0

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  6488.000000  6493.000000  6497.000000  6497.000000
# mean      3.218395     0.531215    10.491801     5.818378
# std       0.160748     0.148814     1.192712     0.873255
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.110000     0.430000     9.500000     5.000000
# 50%       3.210000     0.510000    10.300000     6.000000
# 75%       3.320000     0.600000    11.300000     6.000000
# max       4.010000     2.000000    14.900000     9.000000

# %%
df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.045                 45.0                 170.0  1.00100  3.00
# 1         0.049                 14.0                 132.0  0.99400  3.30
# 2         0.050                 30.0                  97.0  0.99510  3.26
# 3         0.058                 47.0                 186.0  0.99560  3.19
# 4         0.058                 47.0                 186.0  0.99560  3.19
# ...         ...                  ...                   ...      ...   ...
# 6492      0.090                 32.0                  44.0  0.99490  3.45
# 6493      0.062                 39.0                  51.0  0.99512  3.52
# 6494      0.076                 29.0                  40.0  0.99574  3.42
# 6495      0.075                 32.0                  44.0  0.99547  3.57
# 6496      0.067                 18.0                  42.0  0.99549  3.39
#
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# ...         ...      ...      ...
# 6492       0.58     10.5        5
# 6493        NaN     11.2        6
# 6494       0.75     11.0        6
# 6495       0.71     10.2        5
# 6496       0.66     11.0        6
#
# [6497 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.221066     0.323744
# volatile acidity           0.221066          1.000000    -0.377512
# citric acid                0.323744         -0.377512     1.000000
# residual sugar            -0.113442         -0.196677     0.142324
# chlorides                  0.299104          0.377995     0.039412
# free sulfur dioxide       -0.283485         -0.353402     0.132271
# total sulfur dioxide      -0.330543         -0.414729     0.194398
# density                    0.459713          0.272101     0.097068
# pH                        -0.251121          0.260134    -0.327860
# sulphates                  0.301263          0.225656     0.059070
# alcohol                   -0.096190         -0.039528    -0.010056
# quality                   -0.076174         -0.266677     0.084926
# type_white                -0.488552         -0.653374     0.185892
# Excellent quality         -0.049347         -0.151756     0.053870
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity              -0.113442   0.299104            -0.283485
# volatile acidity           -0.196677   0.377995            -0.353402
# citric acid                 0.142324   0.039412             0.132271
# residual sugar              1.000000  -0.128814             0.403449
# chlorides                  -0.128814   1.000000            -0.195428
# free sulfur dioxide         0.403449  -0.195428             1.000000
# total sulfur dioxide        0.495684  -0.279602             0.721476
# density                     0.551494   0.363108             0.025113
# pH                         -0.266481   0.044653            -0.145164
# sulphates                  -0.185616   0.396240            -0.188947
# alcohol                    -0.359132  -0.257664            -0.179477
# quality                    -0.034654  -0.200553             0.054924
# type_white                  0.349358  -0.512705             0.472653
# Excellent quality          -0.062492  -0.161593             0.014821
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.330543  0.459713 -0.251121   0.301263
# volatile acidity                 -0.414729  0.272101  0.260134   0.225656
# citric acid                       0.194398  0.097068 -0.327860   0.059070
# residual sugar                    0.495684  0.551494 -0.266481  -0.185616
# chlorides                        -0.279602  0.363108  0.044653   0.396240
# free sulfur dioxide               0.721476  0.025113 -0.145164  -0.188947
# total sulfur dioxide              1.000000  0.031419 -0.237204  -0.275878
# density                           0.031419  1.000000  0.012525   0.260019
# pH                               -0.237204  0.012525  1.000000   0.190864
# sulphates                        -0.275878  0.260019  0.190864   1.000000
# alcohol                          -0.264385 -0.687432  0.120473  -0.004116
# quality                          -0.041598 -0.304447  0.018403   0.039054
# type_white                        0.700521 -0.391437 -0.328474  -0.486715
# Excellent quality                -0.051459 -0.274404  0.027553   0.034767
#
#                        alcohol   quality  type_white  Excellent quality
# fixed acidity        -0.096190 -0.076174   -0.488552          -0.049347
# volatile acidity     -0.039528 -0.266677   -0.653374          -0.151756
# citric acid          -0.010056  0.084926    0.185892           0.053870
# residual sugar       -0.359132 -0.034654    0.349358          -0.062492
# chlorides            -0.257664 -0.200553   -0.512705          -0.161593
# free sulfur dioxide  -0.179477  0.054924    0.472653           0.014821
# total sulfur dioxide -0.264385 -0.041598    0.700521          -0.051459
# density              -0.687432 -0.304447   -0.391437          -0.274404
# pH                    0.120473  0.018403   -0.328474           0.027553
# sulphates            -0.004116  0.039054   -0.486715           0.034767
# alcohol               1.000000  0.444637    0.035095           0.390937
# quality               0.444637  1.000000    0.119185           0.759495
# type_white            0.035095  0.119185    1.000000           0.086964
# Excellent quality     0.390937  0.759495    0.086964           1.000000

# %%
df.skew()
# Out:
# fixed acidity           1.721648
# volatile acidity        1.500040
# citric acid             0.474907
# residual sugar          1.437126
# chlorides               5.403432
# free sulfur dioxide     1.223427
# total sulfur dioxide   -0.000425
# density                 0.504204
# pH                      0.391094
# sulphates               1.802941
# alcohol                 0.565435
# quality                 0.189878
# dtype: float64

# %%
df = pd.get_dummies(df,drop_first=True)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 6491            6.8             0.620         0.08             1.9      0.068
# 6492            6.2             0.600         0.08             2.0      0.090
# 6494            6.3             0.510         0.13             2.3      0.076
# 6495            5.9             0.645         0.12             2.0      0.075
# 6496            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 6491                 28.0                  38.0  0.99651  3.42       0.82
# 6492                 32.0                  44.0  0.99490  3.45       0.58
# 6494                 29.0                  40.0  0.99574  3.42       0.75
# 6495                 32.0                  44.0  0.99547  3.57       0.71
# 6496                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality  type_white
# 0         8.8        6           1
# 1         9.5        6           1
# 2        10.1        6           1
# 3         9.9        6           1
# 4         9.9        6           1
# ...       ...      ...         ...
# 6491      9.5        6           0
# 6492     10.5        5           0
# 6494     11.0        6           0
# 6495     10.2        5           0
# 6496     11.0        6           0
#
# [6463 rows x 13 columns]

# %%
df['Excellent quality'] = [ 1 if x>=7 else 0 for x in df.quality] 
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 6491            6.8             0.620         0.08             1.9      0.068
# 6492            6.2             0.600         0.08             2.0      0.090
# 6494            6.3             0.510         0.13             2.3      0.076
# 6495            5.9             0.645         0.12             2.0      0.075
# 6496            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    45.0                 170.0  1.00100  3.00       0.45
# 1                    14.0                 132.0  0.99400  3.30       0.49
# 2                    30.0                  97.0  0.99510  3.26       0.44
# 3                    47.0                 186.0  0.99560  3.19       0.40
# 4                    47.0                 186.0  0.99560  3.19       0.40
# ...                   ...                   ...      ...   ...        ...
# 6491                 28.0                  38.0  0.99651  3.42       0.82
# 6492                 32.0                  44.0  0.99490  3.45       0.58
# 6494                 29.0                  40.0  0.99574  3.42       0.75
# 6495                 32.0                  44.0  0.99547  3.57       0.71
# 6496                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality  type_white  Excellent quality
# 0         8.8        6           1                  0
# 1         9.5        6           1                  0
# 2        10.1        6           1                  0
# 3         9.9        6           1                  0
# 4         9.9        6           1                  0
# ...       ...      ...         ...                ...
# 6491      9.5        6           0                  0
# 6492     10.5        5           0                  0
# 6494     11.0        6           0                  0
# 6495     10.2        5           0                  0
# 6496     11.0        6           0                  0
#
# [6463 rows x 14 columns]

# %%
y = df["Excellent quality"]

# %%
x = df.drop(['quality','Excellent quality'], axis = 1)

# %%
plt.figure(figsize= (12,12))
sns.heatmap(df.corr(), square=True , annot = True,cmap="BuPu")

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2 ,random_state = 30 )
from sklearn.metrics import accuracy_score

# %%
#Knn

from sklearn.neighbors import KNeighborsClassifier 
model1 = KNeighborsClassifier(n_neighbors=3)
model1.fit(x_train,y_train)
y_pred1 = model1.predict(x_test)


lr =(accuracy_score(y_test,y_pred1))
print(lr)
# Out:
# 0.7989172467130704

# %%
#Decision Tree

from sklearn.tree import DecisionTreeClassifier
model2 = DecisionTreeClassifier(criterion='entropy',random_state=7)
model2.fit(x_train,y_train)
y_pred2 = model2.predict(x_test)

dt =(accuracy_score(y_test,y_pred2))
print(dt)
# Out:
# 0.8445475638051044

# %%
#RandomForest

from sklearn.ensemble import RandomForestClassifier
model3 = RandomForestClassifier(random_state=1)
model3.fit(x_train, y_train)
y_pred3 = model3.predict(x_test)


rf =(accuracy_score(y_test,y_pred3))
print(rf)
# Out:
# 0.880123743232792

# %%
#SVM

from sklearn.svm import SVC
model2 = SVC()
model2.fit(x_train,y_train)
y_pred2 = model2.predict(x_test)

svm = (accuracy_score(y_test,y_pred2))
print(svm)
# Out:
# 0.7996906419180201

# %%
models = pd.DataFrame({'models' : ["Knn" , "Decision Tree" , "RandomForest" , "SVM"] , 'Acurracy score' : [lr,dt,rf,svm]})
models.sort_values(by ="Acurracy score" ,  ascending = False)
# Out:
#           models  Acurracy score
# 2   RandomForest        0.880124
# 1  Decision Tree        0.844548
# 3            SVM        0.799691
# 0            Knn        0.798917
